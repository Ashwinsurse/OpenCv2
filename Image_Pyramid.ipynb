# %%
# Importing necessary library

import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
# Reading the image
img = cv2.imread('flower.jpg')

#Image Small and larage
smaller = cv2.pyrDown(img)
#larger = cv2.pyrUp(img)

#cv2_imshow(img)
cv2_imshow(smaller)
#cv2_imshow(larger)
# Out:
# <PIL.Image.Image image mode=RGB size=1152x1536 at 0x7F888301E250>
